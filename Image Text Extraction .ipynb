# %% [markdown]
# #  Import Libraries:

# %%
import cv2
import pytesseract
from matplotlib import pyplot as plt

# %% [markdown]
# # Load and Preprocess the Image

# %%
def load_and_preprocess_image(image_path):
    image = cv2.imread(image_path)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    blurred = cv2.GaussianBlur(gray, (5, 5), 0)
    return blurred

# %% [markdown]
# # Extract Text from Image

# %%
def extract_text_from_image(image_path):
    preprocessed_image = load_and_preprocess_image(image_path)
    text = pytesseract.image_to_string(preprocessed_image)
    return text

# %% [markdown]
# # Image with Extracted Text

# %%
image_path = 'task2/1.png'  # Provide the path to the image you want to process
extracted_text = extract_text_from_image(image_path)
print("Extracted Text:")
print(extracted_text)

# Display the image and extracted text
image = cv2.imread(image_path)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title("Image with Extracted Text")
plt.show()
# Out:
# Extracted Text:
# 5 iGil Ks ae
# Ee: 06/07-23
# USP &2.0.07 710
#
# (indusive of all taxes) Batch No. “v
#
# TER

# %%
image_path = 'task2/2.png'  # Provide the path to the image you want to process
extracted_text = extract_text_from_image(image_path)
print("Extracted Text:")
print(extracted_text)

# Display the image and extracted text
image = cv2.imread(image_path)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title("Image with Extracted Text")
plt.show()
# Out:
# Extracted Text:

# %%
image_path = 'task2/3.png'  # Provide the path to the image you want to process
extracted_text = extract_text_from_image(image_path)
print("Extracted Text:")
print(extracted_text)

# Display the image and extracted text
image = cv2.imread(image_path)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title("Image with Extracted Text")
plt.show()
# Out:
# Extracted Text:
# Sant
# F Re.0.07 1
#
# i all faxes) Batch No. “r,s

# %%
image_path = 'task2/4.png'  # Provide the path to the image you want to process
extracted_text = extract_text_from_image(image_path)
print("Extracted Text:")
print(extracted_text)

# Display the image and extracted text
image = cv2.imread(image_path)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title("Image with Extracted Text")
plt.show()
# Out:
# Extracted Text:

# %%
image_path = 'task2/5.png'  # Provide the path to the image you want to process
extracted_text = extract_text_from_image(image_path)
print("Extracted Text:")
print(extracted_text)

# Display the image and extracted text
image = cv2.imread(image_path)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title("Image with Extracted Text")
plt.show()
# Out:
# Extracted Text:
# 23-12-42
# ADSKinii 3 0--
# EMPG-07.33, oO,
# ry R25 “(1 7

# %%
image_path = 'task2/6.png'  # Provide the path to the image you want to process
extracted_text = extract_text_from_image(image_path)
print("Extracted Text:")
print(extracted_text)

# Display the image and extracted text
image = cv2.imread(image_path)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title("Image with Extracted Text")
plt.show()
# Out:
# Extracted Text:
# ees 17:42 —
#
# S.U-—
# iPoc/o7-230 of cs
# 2.0.07 -m
#
# of all faxes) Batch No. °7
#
# rep yo
#
# —

# %%
image_path = 'task2/7.png'  # Provide the path to the image you want to process
extracted_text = extract_text_from_image(image_path)
print("Extracted Text:")
print(extracted_text)

# Display the image and extracted text
image = cv2.imread(image_path)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title("Image with Extracted Text")
plt.show()
# Out:
# Extracted Text:
# BU HFD Ne-mi-23 17:42
#
# 1 &s.10--
# EXP:06 07-23
# hee R2.0.07 mi
#
# (Inclusive of all taxes) Batch No. “»
